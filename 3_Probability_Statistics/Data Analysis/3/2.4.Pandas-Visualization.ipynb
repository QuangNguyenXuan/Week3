# %%
# confusion matrix

import pandas as pd

data = {'Actual Value':    [1, 0, 0, 1, 0, 1, 0, 0, 1],
        'Predicted Value': [0, 1, 0, 1, 0, 1, 1, 0, 1]}
df = pd.DataFrame(data)
df
# Out:
#    Actual Value  Predicted Value
# 0             1                0
# 1             0                1
# 2             0                0
# 3             1                1
# 4             0                0
# 5             1                1
# 6             0                1
# 7             0                0
# 8             1                1

# %%
confusion_matrix = pd.crosstab(df['Predicted Value'], df['Actual Value'],
                               rownames=['Predicted'], colnames=['Actual'])
print(confusion_matrix)
# Out:
# Actual     0  1
# Predicted
# 0          3  1
# 1          2  3

# %%
import seaborn as sn
import matplotlib.pyplot as plt
#%matplotlib qt

sn.heatmap(confusion_matrix, annot=True)
plt.show()

# %% [markdown]
# ## advertising

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
#%matplotlib qt

df = pd.read_csv('advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.to_numpy()
# Out:
# array([[230.1,  37.8,  69.2,  22.1],
#        [ 44.5,  39.3,  45.1,  10.4],
#        [ 17.2,  45.9,  69.3,  12. ],
#        [151.5,  41.3,  58.5,  16.5],
#        [180.8,  10.8,  58.4,  17.9],
#        [  8.7,  48.9,  75. ,   7.2],
#        [ 57.5,  32.8,  23.5,  11.8],
#        [120.2,  19.6,  11.6,  13.2],
#        [  8.6,   2.1,   1. ,   4.8],
#        [199.8,   2.6,  21.2,  15.6],
#        [ 66.1,   5.8,  24.2,  12.6],
#        [214.7,  24. ,   4. ,  17.4],
#        [ 23.8,  35.1,  65.9,   9.2],
#        [ 97.5,   7.6,   7.2,  13.7],
#        [204.1,  32.9,  46. ,  19. ],
#        [195.4,  47.7,  52.9,  22.4],
#        [ 67.8,  36.6, 114. ,  12.5],
#        [281.4,  39.6,  55.8,  24.4],
#        [ 69.2,  20.5,  18.3,  11.3],
#        [147.3,  23.9,  19.1,  14.6],
#        [218.4,  27.7,  53.4,  18. ],
#        [237.4,   5.1,  23.5,  17.5],
#        [ 13.2,  15.9,  49.6,   5.6],
#        [228.3,  16.9,  26.2,  20.5],
#        [ 62.3,  12.6,  18.3,   9.7],
# ...

# %%
df.plot(x='Radio', y='Sales', kind='scatter',
        figsize=(8,4),
        title='Radio and Sales')
# Out:
# <Axes: title={'center': 'Radio and Sales'}, xlabel='Radio', ylabel='Sales'>

# %%
df.plot(x='TV', y='Sales', kind='scatter',
        figsize=(8,4),
        title='TV and Sales')
# Out:
# <Axes: title={'center': 'TV and Sales'}, xlabel='TV', ylabel='Sales'>

# %%
df.plot(x='Newspaper', y='Sales', kind='scatter',
        figsize=(8,4),
        title='Newspaper and Sales')
# Out:
# <Axes: title={'center': 'Newspaper and Sales'}, xlabel='Newspaper', ylabel='Sales'>

# %% [markdown]
# ## weather

# %%
import pandas as pd

df = pd.read_csv('weatherHistory_4features.csv')
df
# Out:
#                       Formatted Date Precip Type  Temperature (C)  Humidity  \
# 0      2006-04-01 00:00:00.000 +0200        rain         9.472222      0.89
# 1      2006-04-01 01:00:00.000 +0200        rain         9.355556      0.86
# 2      2006-04-01 02:00:00.000 +0200        rain         9.377778      0.89
# 3      2006-04-01 03:00:00.000 +0200        rain         8.288889      0.83
# 4      2006-04-01 04:00:00.000 +0200        rain         8.755556      0.83
# ...                              ...         ...              ...       ...
# 59048  2012-05-31 09:00:00.000 +0200         NaN        20.872222      0.60
# 59049  2012-05-31 10:00:00.000 +0200         NaN        22.611111      0.54
# 59050  2012-05-31 11:00:00.000 +0200        rain        23.783333      0.43
# 59051  2012-05-31 12:00:00.000 +0200        rain        25.000000      0.42
# 59052  2012-05-31 13:00:00.000 +0200        rain        25.000000      0.39
#
#        Wind Speed (km/h)
# 0                14.1197
# ...

# %%
df['Formatted Date']
# Out:
# 0        2006-04-01 00:00:00.000 +0200
# 1        2006-04-01 01:00:00.000 +0200
# 2        2006-04-01 02:00:00.000 +0200
# 3        2006-04-01 03:00:00.000 +0200
# 4        2006-04-01 04:00:00.000 +0200
#                      ...
# 59048    2012-05-31 09:00:00.000 +0200
# 59049    2012-05-31 10:00:00.000 +0200
# 59050    2012-05-31 11:00:00.000 +0200
# 59051    2012-05-31 12:00:00.000 +0200
# 59052    2012-05-31 13:00:00.000 +0200
# Name: Formatted Date, Length: 59053, dtype: object

# %%
df.plot(x='Formatted Date', y='Temperature (C)', kind='line',
        figsize=(8,4),
        title='Temperature (C)')
# Out:
# <Axes: title={'center': 'Temperature (C)'}, xlabel='Formatted Date'>

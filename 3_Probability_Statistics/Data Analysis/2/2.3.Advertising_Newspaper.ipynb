# %% [markdown]
# ## Analyse the Newspaper column

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('advertising.csv')
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df['Newspaper']
# Out:
# 0      69.2
# 1      45.1
# 2      69.3
# 3      58.5
# 4      58.4
#        ...
# 195    13.8
# 196     8.1
# 197     6.4
# 198    66.2
# 199     8.7
# Name: Newspaper, Length: 200, dtype: float64

# %%
data_Newspaper = df['Newspaper'].to_numpy()
print(data_Newspaper.shape)
# Out:
# (200,)

# %%
print(data_Newspaper.mean())
# Out:
# 30.553999999999995

# %%
print(data_Newspaper.std())
# Out:
# 21.724106057557353

# %%
print(data_Newspaper.min())
# Out:
# 0.3

# %%
print(data_Newspaper.max())
# Out:
# 114.0

# %%
#!pip install PyQt5

# %%
import seaborn as sn
import matplotlib.pyplot as plt
#%matplotlib qt

data_sales = df['Sales'].to_numpy()

# %%
plt.scatter(data_Newspaper, data_sales)

# %%
df.plot(x='Newspaper', y='Sales', kind='scatter',
        figsize=(6,4),
        title='Newspaper and Sales')
# Out:
# <Axes: title={'center': 'Newspaper and Sales'}, xlabel='Newspaper', ylabel='Sales'>

# %% [markdown]
# #### check percentile

# %%
data_newspaper_50 = data_Newspaper[data_Newspaper < 25.75]
print(data_newspaper_50.shape)
# Out:
# (100,)

# %%
data_newspaper_50
# Out:
# array([23.5, 11.6,  1. , 21.2, 24.2,  4. ,  7.2, 18.3, 19.1, 23.5, 18.3,
#        19.5, 12.6, 22.9, 22.9,  0.3,  7.4,  8.5,  5. ,  1.8, 18.5,  3.6,
#        15.9, 16.6,  9.3, 21.4,  8.4,  0.9,  2.2, 10.2, 11. , 19.3, 13.1,
#        20.7, 14.2,  9.4, 23.1, 22.3, 16. ,  9.3, 10.9,  5.9, 22. , 21.4,
#        17.9,  5.3, 23.2, 25.6,  5.5, 23.2,  2.4, 10.7, 25.6, 14.8, 22.3,
#        15.6, 12.4,  9.2,  3.2,  8.7,  2.1,  8.5,  9.3, 20.5,  1.7, 12.9,
#         9. ,  8.7, 11.9, 20.6, 14.2,  9.5,  5.7, 24.3, 25.6,  7.4,  5.4,
#        21.6, 19.4,  6.4, 18.4, 17. , 12.8, 13.1, 20.3, 23.7, 17.6,  8.3,
#        19.6, 18.2,  3.7, 23.4,  5.8,  6. ,  3.6,  6. , 13.8,  8.1,  6.4,
#         8.7])

# %% [markdown]
# #### histogram

# %%
plt.hist(data_Newspaper, bins=40)
plt.plot()
# Out:
# []

# %%
df['Newspaper'].plot.hist(bins=40)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.boxplot(data_Newspaper)
plt.plot()
# Out:
# []
